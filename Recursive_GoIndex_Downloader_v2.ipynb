# %% [markdown]
# ## Recursive GoIndex Downloader by atlonxp
#
# This code was created and improved by adapting the code from pankaj260 https://colab.research.google.com/drive/1tmsLGuswIZIZ_oM35EMW8TbJ6pQPt1rY#scrollTo=3bCnUMUg_SoT&forceEdit=true&sandboxMode=true
#
# **Features**
# *   Recursive crawler (atlonxp)
# *   Download all folders and files in a given url (atlonxp)
# *   Download all folders and files in in sub-folders (atlonxp)
# *   Adaptive delay in fetching url (atlonxp)
# *   Store folders/files directly to your Google Drive (pankaj260)
# *   Folders and files exclusion filters
# *   Download queue supported
# *   Auto-domain URL detection
# *   API-based GoIndex crawler
# *   Parallel/Multiple files downloader
#
# **Version 2**:
#
# 	16 April 2020
#
# 	+ crawler_v2:
# 		* API-based GoIndex crawler
# 		* Collecting all urls to be downloaded
# 	+ parallel downloader
# 		* TQDM progress bar
#
# **Version 1**:
#
# 	15 April 2020
# 	-   Added auto-domain URL detection
# 	-   Added simple download queue
#
# 	14 April 2020
# 		-   initial

# %%
# Mounting Google Drive, ignore this section if you don't want to 
# save on your Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Install dependencies
# !pip install requests tqdm

# %%
# Import dependencies

import json
import multiprocessing
import os
from random import randint
from time import sleep
from urllib import parse

import requests
import tqdm

# %%
OVERWRITE = True
MIN_DELAY = 2
MAX_DELAY = 5
def check_exclusion(name, exclusions):
    for exc in exclusions:
        if exc in name:
            return True
    return False


def crawler_v2(url, downloading_dict, path, level, exclusions, verbose=False):
    if not os.path.exists(path):
        os.mkdir(path)

    url = parse.urlparse(url)
    print(('  ' * level) + url.geturl())

    response = requests.post(url.geturl(), data={})
    files_dict = json.loads(response.text)['files']

    for file in files_dict:
        name = file['name']

        # if @name contains exclusion word, we ignore
        if check_exclusion(name, exclusions):
            continue

        if 'folder' in file['mimeType']:
            next_url = url.geturl() + parse.quote(name) + "/"
            next_path = os.path.join(path, name)
            crawler_v2(next_url, downloading_dict, next_path, level + 1, exclusions, verbose)
        else:
            name = file['name']
            if verbose:
                print('  ' * (level + 1) + name)

            downloading_dict.append({
                'folder': path,
                'filename': name,
                'filename_abs': os.path.join(path, name),
                'size': file['size'],
                'url': url.geturl() + parse.quote(name),
            })

    return downloading_dict


def download_agent(task, OVERWRITE=OVERWRITE):
    # Making multiple requests too quick can cause yourself banned, so let set random delay (1, 10)
    sleep(randint(MIN_DELAY, MAX_DELAY))

    folder = task['folder']
    filename_abs = task['filename_abs']
    url = task['url']

    if not os.path.exists(folder):
        os.mkdir(folder)
    if os.path.exists(filename_abs) or OVERWRITE:
        r = requests.get(url, stream=True)
        if r.status_code is not 200:
            return 1
        with open(filename_abs, 'ab+') as f:
            f.write(r.content)
    return 0

# %%
MAX_DOWNLOAD_TASKS = 8
exclusions = ['__MACOSX/']

destination = "/content/drive/My Drive/"
download_tasks = [
    {
        'folder': 'AI Product Manager Nanodegree v1.0.0',
        'url': 'https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/'
    },
    {
        'folder': 'Data Science Nanodegree v1.0.0',
        'url': 'https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/D.S.ND%20v1.0.0/'
    },
]

print('##################################')
print('# Crawling all downloadable urls #')
print('##################################', end='\n\n')
tasks = []
for task in download_tasks:
	tasks += crawler_v2(task['url'], tasks, os.path.join(destination, task['folder']), 0, exclusions)

# print(json.dumps(tasks, indent=2))

print('##################################')
print('# Downloading files and folders  #')
print('##################################', end='\n\n')
pool = multiprocessing.Pool(processes=MAX_DOWNLOAD_TASKS)  # Num of CPUs

failures = sum(tqdm.tqdm(pool.imap_unordered(download_agent, tasks), total=len(tasks)))
print('Total number of download failures:', failures)
pool.close()
pool.terminate()

print('\nAll done, Voila!')
# Out:
# ##################################
# # Crawling all downloadable urls #
# ##################################
#
# https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/
#   https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/
# https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/img/
# [
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_AMS-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_AMS-Regular.ttf",
#     "size": "71428",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_AMS-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_AMS-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_AMS-Regular.woff",
#     "size": "40200",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_AMS-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_AMS-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_AMS-Regular.woff2",
#     "size": "33208",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_AMS-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Bold.ttf",
#     "size": "19588",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Bold.woff",
#     "size": "12136",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Bold.woff2",
#     "size": "10596",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Regular.ttf",
#     "size": "18960",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Regular.woff",
#     "size": "11868",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Regular.woff2",
#     "size": "10412",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Bold.ttf",
#     "size": "35968",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Bold.woff",
#     "size": "23388",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Bold.woff2",
#     "size": "20488",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Regular.ttf",
#     "size": "34652",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Regular.woff",
#     "size": "22844",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Regular.woff2",
#     "size": "19860",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Bold.ttf",
#     "size": "61712",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Bold.woff",
#     "size": "36752",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Bold.woff2",
#     "size": "30620",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-BoldItalic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-BoldItalic.ttf",
#     "size": "44824",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-BoldItalic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-BoldItalic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-BoldItalic.woff",
#     "size": "26228",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-BoldItalic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-BoldItalic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-BoldItalic.woff2",
#     "size": "22188",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-BoldItalic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Italic.ttf",
#     "size": "47952",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Italic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Italic.woff",
#     "size": "27200",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Italic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Italic.woff2",
#     "size": "23056",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Regular.ttf",
#     "size": "70076",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Regular.woff",
#     "size": "39444",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Regular.woff2",
#     "size": "32864",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-BoldItalic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-BoldItalic.ttf",
#     "size": "39744",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-BoldItalic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-BoldItalic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-BoldItalic.woff",
#     "size": "23192",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-BoldItalic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-BoldItalic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-BoldItalic.woff2",
#     "size": "20044",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-BoldItalic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.ttf",
#     "size": "41448",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.woff",
#     "size": "23820",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.woff2",
#     "size": "20432",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.ttf",
#     "size": "34032",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.woff",
#     "size": "19172",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.woff2",
#     "size": "15996",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.ttf",
#     "size": "31308",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.woff",
#     "size": "18128",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.woff2",
#     "size": "15212",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Regular.ttf",
#     "size": "30156",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Regular.woff",
#     "size": "16784",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Regular.woff2",
#     "size": "14024",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Script-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Script-Regular.ttf",
#     "size": "24864",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Script-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Script-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Script-Regular.woff",
#     "size": "13856",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Script-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Script-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Script-Regular.woff2",
#     "size": "12276",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Script-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size1-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size1-Regular.ttf",
#     "size": "13172",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size1-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size1-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size1-Regular.woff",
#     "size": "6980",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size1-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size1-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size1-Regular.woff2",
#     "size": "5824",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size1-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size2-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size2-Regular.ttf",
#     "size": "12412",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size2-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size2-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size2-Regular.woff",
#     "size": "6684",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size2-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size2-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size2-Regular.woff2",
#     "size": "5560",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size2-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size3-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size3-Regular.ttf",
#     "size": "8360",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size3-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size3-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size3-Regular.woff",
#     "size": "4776",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size3-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size3-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size3-Regular.woff2",
#     "size": "3856",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size3-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size4-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size4-Regular.ttf",
#     "size": "11284",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size4-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size4-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size4-Regular.woff",
#     "size": "6456",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size4-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size4-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size4-Regular.woff2",
#     "size": "5184",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size4-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Typewriter-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Typewriter-Regular.ttf",
#     "size": "36308",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Typewriter-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Typewriter-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Typewriter-Regular.woff",
#     "size": "20920",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Typewriter-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Typewriter-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Typewriter-Regular.woff2",
#     "size": "17540",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Typewriter-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "bootstrap.min.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/bootstrap.min.css",
#     "size": "140942",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/bootstrap.min.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "jquery.mCustomScrollbar.min.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/jquery.mCustomScrollbar.min.css",
#     "size": "42839",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/jquery.mCustomScrollbar.min.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "katex.min.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/katex.min.css",
#     "size": "22078",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/katex.min.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "plyr.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/plyr.css",
#     "size": "24182",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/plyr.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "styles.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/styles.css",
#     "size": "4114",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/styles.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_AMS-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_AMS-Regular.ttf",
#     "size": "71428",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_AMS-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_AMS-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_AMS-Regular.woff",
#     "size": "40200",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_AMS-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_AMS-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_AMS-Regular.woff2",
#     "size": "33208",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_AMS-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Bold.ttf",
#     "size": "19588",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Bold.woff",
#     "size": "12136",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Bold.woff2",
#     "size": "10596",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Regular.ttf",
#     "size": "18960",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Regular.woff",
#     "size": "11868",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Caligraphic-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Caligraphic-Regular.woff2",
#     "size": "10412",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Caligraphic-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Bold.ttf",
#     "size": "35968",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Bold.woff",
#     "size": "23388",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Bold.woff2",
#     "size": "20488",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Regular.ttf",
#     "size": "34652",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Regular.woff",
#     "size": "22844",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Fraktur-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Fraktur-Regular.woff2",
#     "size": "19860",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Fraktur-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Bold.ttf",
#     "size": "61712",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Bold.woff",
#     "size": "36752",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Bold.woff2",
#     "size": "30620",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-BoldItalic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-BoldItalic.ttf",
#     "size": "44824",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-BoldItalic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-BoldItalic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-BoldItalic.woff",
#     "size": "26228",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-BoldItalic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-BoldItalic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-BoldItalic.woff2",
#     "size": "22188",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-BoldItalic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Italic.ttf",
#     "size": "47952",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Italic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Italic.woff",
#     "size": "27200",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Italic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Italic.woff2",
#     "size": "23056",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Regular.ttf",
#     "size": "70076",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Regular.woff",
#     "size": "39444",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Main-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Main-Regular.woff2",
#     "size": "32864",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Main-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-BoldItalic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-BoldItalic.ttf",
#     "size": "39744",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-BoldItalic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-BoldItalic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-BoldItalic.woff",
#     "size": "23192",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-BoldItalic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-BoldItalic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-BoldItalic.woff2",
#     "size": "20044",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-BoldItalic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.ttf",
#     "size": "41448",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.woff",
#     "size": "23820",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.woff2",
#     "size": "20432",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.ttf",
#     "size": "34032",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.woff",
#     "size": "19172",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.woff2",
#     "size": "15996",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.ttf",
#     "size": "31308",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.woff",
# ...
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Math-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Math-Italic.woff2",
#     "size": "20432",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Math-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.ttf",
#     "size": "34032",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.woff",
#     "size": "19172",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Bold.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Bold.woff2",
#     "size": "15996",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Bold.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.ttf",
#     "size": "31308",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.woff",
#     "size": "18128",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Italic.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Italic.woff2",
#     "size": "15212",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Italic.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Regular.ttf",
#     "size": "30156",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Regular.woff",
#     "size": "16784",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_SansSerif-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_SansSerif-Regular.woff2",
#     "size": "14024",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_SansSerif-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Script-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Script-Regular.ttf",
#     "size": "24864",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Script-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Script-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Script-Regular.woff",
#     "size": "13856",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Script-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Script-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Script-Regular.woff2",
#     "size": "12276",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Script-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size1-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size1-Regular.ttf",
#     "size": "13172",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size1-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size1-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size1-Regular.woff",
#     "size": "6980",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size1-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size1-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size1-Regular.woff2",
#     "size": "5824",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size1-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size2-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size2-Regular.ttf",
#     "size": "12412",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size2-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size2-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size2-Regular.woff",
#     "size": "6684",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size2-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size2-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size2-Regular.woff2",
#     "size": "5560",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size2-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size3-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size3-Regular.ttf",
#     "size": "8360",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size3-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size3-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size3-Regular.woff",
#     "size": "4776",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size3-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size3-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size3-Regular.woff2",
#     "size": "3856",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size3-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size4-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size4-Regular.ttf",
#     "size": "11284",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size4-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size4-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size4-Regular.woff",
#     "size": "6456",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size4-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Size4-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Size4-Regular.woff2",
#     "size": "5184",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Size4-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Typewriter-Regular.ttf",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Typewriter-Regular.ttf",
#     "size": "36308",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Typewriter-Regular.ttf"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Typewriter-Regular.woff",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Typewriter-Regular.woff",
#     "size": "20920",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Typewriter-Regular.woff"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts",
#     "filename": "KaTeX_Typewriter-Regular.woff2",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/fonts/KaTeX_Typewriter-Regular.woff2",
#     "size": "17540",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/fonts/KaTeX_Typewriter-Regular.woff2"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "bootstrap.min.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/bootstrap.min.css",
#     "size": "140942",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/bootstrap.min.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "jquery.mCustomScrollbar.min.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/jquery.mCustomScrollbar.min.css",
#     "size": "42839",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/jquery.mCustomScrollbar.min.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "katex.min.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/katex.min.css",
#     "size": "22078",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/katex.min.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "plyr.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/plyr.css",
#     "size": "24182",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/plyr.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC",
#     "filename": "styles.css",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/ABC/styles.css",
#     "size": "4114",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/css/styles.css"
#   },
#   {
#     "folder": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/DEF",
#     "filename": "udacimak.png",
#     "filename_abs": "/Users/atlonxp/Desktop/recursive-goIndex-downloader/download/DEF/udacimak.png",
#     "size": "472136",
#     "url": "https://lol.freecoronavirus.workers.dev/Udacity%20-%20Collections%20[300%20GB]/Nanodegrees/AI%20Product%20Manager%20ND%20v1.0.0/assets/img/udacimak.png"
#   }
# ]
# ##################################
# # Downloading files and folders  #
# ##################################
#
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#   5%|▍         | 12/262 [00:18<05:36,  1.35s/it]
